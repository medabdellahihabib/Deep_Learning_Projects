# %% [markdown]
# # What is Deep learning?
# Deep Learning is a subfield of machine learning concerned with algorithms inspired by the structure and function of the brain called artificial neural networks. Deep learning is a machine learning technique that teaches computers to do what comes naturally to humans: learn by example. Deep learning is a key technology behind driverless cars, enabling them to recognize a stop sign, or to distinguish a pedestrian from a lamppost. It is the key to voice control in consumer devices like phones, tablets, TVs, and hands-free speakers. Deep learning is getting lots of attention lately and for good reason. It’s achieving results that were not possible before.
#
#
# # What are artificial neural networks?
# An artificial neuron network (ANN) is a computational model based on the structure and functions of biological neural networks. Information that flows through the network affects the structure of the ANN because a neural network changes - or learns, in a sense - based on that input and output. ANNs are considered nonlinear statistical data modeling tools where the complex relationships between inputs and outputs are modeled or patterns are found. ANN is also known as a neural network.

# %% [markdown]
# <img src="https://cdn-images-1.medium.com/max/1000/1*ZX05x1xYgaVoa4Vn2kKS9g.png">

# %% [markdown]
# A single neuron is known as a perceptron. It consists of a layer of inputs(corresponds to columns of a dataframe). Each input has a weight which controls the magnitude of an input.
# The summation of the products of these input values and weights is fed to the activation function. Activation functions are really important for a Artificial Neural Network to learn and make sense of something really complicated and Non-linear complex functional mappings between the inputs and response variable.
#
# They introduce non-linear properties to our Network.Their main purpose is to convert a input signal of a node in a A-NN to an output signal. That output signal now is used as a input in the next layer in the stack.  Specifically in A-NN we do the sum of products of inputs(X) and their corresponding Weights(W) and apply a Activation function f(x) to it to get the output of that layer and feed it as an input to the next layer. [Refer to this article for more info.](https://towardsdatascience.com/activation-functions-and-its-types-which-is-better-a9a5310cc8f)
# <img src="https://cdnpythonmachinelearning.azureedge.net/wp-content/uploads/2017/09/Single-Perceptron.png">
# **Concept of backpropagation** - Backpropagation, short for "backward propagation of errors," is an algorithm for supervised learning of artificial neural networks using gradient descent. Given an artificial neural network and an error function, the method calculates the gradient of the error function with respect to the neural network's weights. It is a generalization of the delta rule for perceptrons to multilayer feedforward neural networks.
# <img src="https://www.researchgate.net/profile/Hassan_Al-Haj_Ibrahim/publication/235338024/figure/fig6/AS:299794191929349@1448487913220/Flow-chart-for-the-back-propagation-BP-learning-algorithm.png">
# **Gradient Descent** - To explain Gradient Descent I’ll use the classic mountaineering example. Suppose you are at the top of a mountain, and you have to reach a lake which is at the lowest point of the mountain (a.k.a valley). A twist is that you are blindfolded and you have zero visibility to see where you are headed. So, what approach will you take to reach the lake? The best way is to check the ground near you and observe where the land tends to descend. This will give an idea in what direction you should take your first step. If you follow the descending path, it is very likely you would reach the lake. [Refer to this article for more information.](https://www.analyticsvidhya.com/blog/2017/03/introduction-to-gradient-descent-algorithm-along-its-variants/)

# %% [markdown]
# About Breast Cancer Wisconsin (Diagnostic) Data Set
# Features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass. They describe characteristics of the cell nuclei present in the image. n the 3-dimensional space is that described in: [K. P. Bennett and O. L. Mangasarian: "Robust Linear Programming Discrimination of Two Linearly Inseparable Sets", Optimization Methods and Software 1, 1992, 23-34].
#
# This database is also available through the UW CS ftp server: ftp ftp.cs.wisc.edu cd math-prog/cpo-dataset/machine-learn/WDBC/
#
# Also can be found on UCI Machine Learning Repository: https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('/content/data.csv')

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
X = data.iloc[:, 2:].values
y = data.iloc[:, 1].values

from sklearn.preprocessing import LabelEncoder
labelencoder_X_1 = LabelEncoder()
y = labelencoder_X_1.fit_transform(y)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 0)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train.shape
# Out:
# (512, 30)

# %% [markdown]
# **Now that we have prepared data, we will import Keras and its packages.**

# %%
import keras
from keras.layers import Dropout
from keras.models import Sequential
from keras.layers import Dense

# %%
classifier = Sequential()
classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 30))
classifier.add(Dropout(rate = 0.1))
classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dropout(rate = 0.1))
classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dropout(rate = 0.1))
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))  # 0 - 1   >=0.5 ? 1 , 0
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
classifier.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,057 (4.13 KB)
#  Trainable params: 1,057 (4.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# input_dim - number of columns of the dataset
#
# output_dim - number of outputs to be fed to the next layer, if any
#
# activation - activation function which is ReLU in this case
#
# init - the way in which weights should be provided to an ANN
#
# When you use **kernel_initializer='uniform'**, it means that the weights of the layer are initialized by drawing random values from a uniform distribution. Specifically, the weights are initialized with values from a uniform distribution within a specific

# %% [markdown]
# output_dim is 1 as we want only 1 output from the final layer.

# %%
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Optimizer is chosen as adam for gradient descent.
#
# Binary_crossentropy is the loss function used.
#
# Cross-entropy loss, or log loss, measures the performance of a classification model whose output is a probability value between 0 and 1. Cross-entropy loss increases as the predicted probability diverges from the actual label. So predicting a probability of .012 when the actual observation label is 1 would be bad and result in a high loss value.

# %%
history=classifier.fit(X_train, y_train,validation_split=0.2, batch_size=32, epochs=200)
# Out:
# Epoch 1/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - accuracy: 0.6634 - loss: 0.6927 - val_accuracy: 0.6019 - val_loss: 0.6915
# Epoch 2/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6398 - loss: 0.6902 - val_accuracy: 0.6019 - val_loss: 0.6868
# Epoch 3/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6530 - loss: 0.6826 - val_accuracy: 0.6311 - val_loss: 0.6706
# Epoch 4/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6951 - loss: 0.6600 - val_accuracy: 0.8738 - val_loss: 0.6243
# Epoch 5/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9031 - loss: 0.5981 - val_accuracy: 0.9612 - val_loss: 0.5250
# Epoch 6/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9449 - loss: 0.4813 - val_accuracy: 0.9709 - val_loss: 0.3837
# Epoch 7/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9532 - loss: 0.3478 - val_accuracy: 0.9806 - val_loss: 0.2629
# Epoch 8/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9565 - loss: 0.2650 - val_accuracy: 0.9806 - val_loss: 0.1811
# Epoch 9/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9565 - loss: 0.1953 - val_accuracy: 0.9903 - val_loss: 0.1270
# Epoch 10/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9541 - loss: 0.1727 - val_accuracy: 0.9903 - val_loss: 0.0971
# Epoch 11/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9797 - loss: 0.1164 - val_accuracy: 0.9806 - val_loss: 0.0783
# Epoch 12/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9786 - loss: 0.1064 - val_accuracy: 0.9806 - val_loss: 0.0671
# Epoch 13/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9664 - loss: 0.1247 - val_accuracy: 0.9806 - val_loss: 0.0589
# Epoch 14/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9872 - loss: 0.0725 - val_accuracy: 0.9806 - val_loss: 0.0519
# Epoch 15/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9770 - loss: 0.0789 - val_accuracy: 0.9806 - val_loss: 0.0485
# Epoch 16/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9806 - loss: 0.0783 - val_accuracy: 0.9806 - val_loss: 0.0440
# Epoch 17/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9813 - loss: 0.0577 - val_accuracy: 0.9806 - val_loss: 0.0405
# Epoch 18/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9831 - loss: 0.0708 - val_accuracy: 0.9806 - val_loss: 0.0402
# Epoch 19/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9870 - loss: 0.0579 - val_accuracy: 0.9806 - val_loss: 0.0385
# Epoch 20/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9837 - loss: 0.0692 - val_accuracy: 0.9806 - val_loss: 0.0370
# Epoch 21/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9847 - loss: 0.0590 - val_accuracy: 0.9806 - val_loss: 0.0348
# Epoch 22/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9794 - loss: 0.0709 - val_accuracy: 0.9806 - val_loss: 0.0331
# Epoch 23/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9779 - loss: 0.0640 - val_accuracy: 0.9903 - val_loss: 0.0304
# Epoch 24/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9779 - loss: 0.0685 - val_accuracy: 0.9903 - val_loss: 0.0298
# Epoch 25/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9835 - loss: 0.0512 - val_accuracy: 0.9903 - val_loss: 0.0270
# Epoch 26/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9799 - loss: 0.0823 - val_accuracy: 0.9903 - val_loss: 0.0272
# Epoch 27/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9819 - loss: 0.0621 - val_accuracy: 0.9903 - val_loss: 0.0266
# Epoch 28/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9893 - loss: 0.0483 - val_accuracy: 0.9903 - val_loss: 0.0257
# Epoch 29/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9822 - loss: 0.0616 - val_accuracy: 0.9903 - val_loss: 0.0254
# Epoch 30/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9869 - loss: 0.0583 - val_accuracy: 0.9903 - val_loss: 0.0254
# Epoch 31/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9684 - loss: 0.0809 - val_accuracy: 0.9903 - val_loss: 0.0243
# Epoch 32/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9776 - loss: 0.0672 - val_accuracy: 1.0000 - val_loss: 0.0240
# Epoch 33/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9866 - loss: 0.0621 - val_accuracy: 1.0000 - val_loss: 0.0244
# Epoch 34/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9884 - loss: 0.0472 - val_accuracy: 1.0000 - val_loss: 0.0232
# Epoch 35/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9861 - loss: 0.0492 - val_accuracy: 1.0000 - val_loss: 0.0219
# Epoch 36/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9877 - loss: 0.0513 - val_accuracy: 1.0000 - val_loss: 0.0238
# Epoch 37/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9743 - loss: 0.0948 - val_accuracy: 0.9903 - val_loss: 0.0226
# Epoch 38/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9915 - loss: 0.0469 - val_accuracy: 0.9903 - val_loss: 0.0207
# Epoch 39/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9857 - loss: 0.0427 - val_accuracy: 1.0000 - val_loss: 0.0194
# Epoch 40/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9734 - loss: 0.0773 - val_accuracy: 1.0000 - val_loss: 0.0198
# Epoch 41/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9906 - loss: 0.0375 - val_accuracy: 1.0000 - val_loss: 0.0188
# Epoch 42/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9841 - loss: 0.0567 - val_accuracy: 1.0000 - val_loss: 0.0198
# Epoch 43/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9876 - loss: 0.0472 - val_accuracy: 1.0000 - val_loss: 0.0195
# Epoch 44/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9811 - loss: 0.0556 - val_accuracy: 1.0000 - val_loss: 0.0179
# Epoch 45/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9854 - loss: 0.0689 - val_accuracy: 1.0000 - val_loss: 0.0179
# Epoch 46/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9878 - loss: 0.0519 - val_accuracy: 1.0000 - val_loss: 0.0175
# Epoch 47/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9975 - loss: 0.0257 - val_accuracy: 1.0000 - val_loss: 0.0158
# Epoch 48/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9878 - loss: 0.0504 - val_accuracy: 1.0000 - val_loss: 0.0172
# Epoch 49/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9863 - loss: 0.0480 - val_accuracy: 1.0000 - val_loss: 0.0174
# Epoch 50/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9951 - loss: 0.0312 - val_accuracy: 1.0000 - val_loss: 0.0173
# Epoch 51/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9883 - loss: 0.0545 - val_accuracy: 0.9903 - val_loss: 0.0182
# Epoch 52/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9850 - loss: 0.0650 - val_accuracy: 0.9903 - val_loss: 0.0177
# Epoch 53/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9859 - loss: 0.0566 - val_accuracy: 1.0000 - val_loss: 0.0166
# Epoch 54/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9843 - loss: 0.0525 - val_accuracy: 1.0000 - val_loss: 0.0155
# Epoch 55/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9879 - loss: 0.0500 - val_accuracy: 1.0000 - val_loss: 0.0164
# Epoch 56/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9912 - loss: 0.0434 - val_accuracy: 1.0000 - val_loss: 0.0154
# Epoch 57/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9930 - loss: 0.0336 - val_accuracy: 1.0000 - val_loss: 0.0144
# Epoch 58/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9815 - loss: 0.0521 - val_accuracy: 1.0000 - val_loss: 0.0146
# Epoch 59/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9871 - loss: 0.0478 - val_accuracy: 1.0000 - val_loss: 0.0155
# Epoch 60/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9839 - loss: 0.0488 - val_accuracy: 1.0000 - val_loss: 0.0161
# Epoch 61/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9958 - loss: 0.0218 - val_accuracy: 1.0000 - val_loss: 0.0139
# Epoch 62/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9885 - loss: 0.0530 - val_accuracy: 1.0000 - val_loss: 0.0148
# Epoch 63/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9939 - loss: 0.0264 - val_accuracy: 1.0000 - val_loss: 0.0151
# Epoch 64/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9837 - loss: 0.0439 - val_accuracy: 1.0000 - val_loss: 0.0150
# Epoch 65/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9910 - loss: 0.0301 - val_accuracy: 1.0000 - val_loss: 0.0142
# Epoch 66/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9887 - loss: 0.0416 - val_accuracy: 0.9903 - val_loss: 0.0146
# Epoch 67/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9939 - loss: 0.0308 - val_accuracy: 1.0000 - val_loss: 0.0139
# Epoch 68/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9882 - loss: 0.0394 - val_accuracy: 0.9903 - val_loss: 0.0149
# Epoch 69/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9937 - loss: 0.0336 - val_accuracy: 1.0000 - val_loss: 0.0129
# Epoch 70/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9860 - loss: 0.0465 - val_accuracy: 1.0000 - val_loss: 0.0132
# Epoch 71/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9867 - loss: 0.0406 - val_accuracy: 1.0000 - val_loss: 0.0133
# Epoch 72/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9934 - loss: 0.0256 - val_accuracy: 1.0000 - val_loss: 0.0125
# Epoch 73/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9879 - loss: 0.0413 - val_accuracy: 1.0000 - val_loss: 0.0131
# Epoch 74/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9935 - loss: 0.0217 - val_accuracy: 1.0000 - val_loss: 0.0123
# Epoch 75/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9827 - loss: 0.0471 - val_accuracy: 0.9903 - val_loss: 0.0140
# Epoch 76/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9881 - loss: 0.0325 - val_accuracy: 0.9903 - val_loss: 0.0141
# Epoch 77/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9912 - loss: 0.0312 - val_accuracy: 0.9903 - val_loss: 0.0158
# Epoch 78/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9888 - loss: 0.0393 - val_accuracy: 0.9903 - val_loss: 0.0152
# Epoch 79/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9885 - loss: 0.0389 - val_accuracy: 0.9903 - val_loss: 0.0161
# Epoch 80/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9928 - loss: 0.0269 - val_accuracy: 0.9903 - val_loss: 0.0154
# Epoch 81/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9956 - loss: 0.0179 - val_accuracy: 0.9903 - val_loss: 0.0150
# Epoch 82/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9947 - loss: 0.0251 - val_accuracy: 0.9903 - val_loss: 0.0158
# Epoch 83/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9891 - loss: 0.0387 - val_accuracy: 0.9903 - val_loss: 0.0181
# Epoch 84/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9931 - loss: 0.0238 - val_accuracy: 0.9903 - val_loss: 0.0155
# Epoch 85/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9929 - loss: 0.0258 - val_accuracy: 0.9903 - val_loss: 0.0170
# Epoch 86/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9959 - loss: 0.0244 - val_accuracy: 0.9903 - val_loss: 0.0146
# Epoch 87/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9910 - loss: 0.0266 - val_accuracy: 0.9903 - val_loss: 0.0121
# Epoch 88/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9871 - loss: 0.0291 - val_accuracy: 0.9903 - val_loss: 0.0133
# Epoch 89/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9967 - loss: 0.0189 - val_accuracy: 0.9903 - val_loss: 0.0133
# Epoch 90/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9911 - loss: 0.0274 - val_accuracy: 0.9903 - val_loss: 0.0135
# Epoch 91/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9946 - loss: 0.0215 - val_accuracy: 0.9903 - val_loss: 0.0136
# Epoch 92/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9874 - loss: 0.0443 - val_accuracy: 0.9903 - val_loss: 0.0134
# Epoch 93/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9915 - loss: 0.0194 - val_accuracy: 0.9903 - val_loss: 0.0127
# Epoch 94/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9865 - loss: 0.0274 - val_accuracy: 0.9903 - val_loss: 0.0141
# Epoch 95/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9967 - loss: 0.0165 - val_accuracy: 0.9903 - val_loss: 0.0130
# Epoch 96/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9899 - loss: 0.0237 - val_accuracy: 0.9903 - val_loss: 0.0158
# Epoch 97/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9855 - loss: 0.0284 - val_accuracy: 0.9903 - val_loss: 0.0135
# Epoch 98/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9924 - loss: 0.0237 - val_accuracy: 0.9903 - val_loss: 0.0153
# Epoch 99/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9988 - loss: 0.0138 - val_accuracy: 0.9903 - val_loss: 0.0133
# Epoch 100/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9920 - loss: 0.0221 - val_accuracy: 0.9903 - val_loss: 0.0177
# Epoch 101/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9948 - loss: 0.0197 - val_accuracy: 0.9903 - val_loss: 0.0220
# Epoch 102/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9892 - loss: 0.0185 - val_accuracy: 0.9903 - val_loss: 0.0175
# Epoch 103/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9963 - loss: 0.0142 - val_accuracy: 0.9903 - val_loss: 0.0171
# Epoch 104/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9901 - loss: 0.0244 - val_accuracy: 0.9903 - val_loss: 0.0186
# Epoch 105/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9990 - loss: 0.0164 - val_accuracy: 0.9903 - val_loss: 0.0153
# Epoch 106/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9906 - loss: 0.0154 - val_accuracy: 0.9903 - val_loss: 0.0161
# Epoch 107/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9971 - loss: 0.0110 - val_accuracy: 0.9903 - val_loss: 0.0167
# Epoch 108/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9980 - loss: 0.0074 - val_accuracy: 0.9903 - val_loss: 0.0161
# Epoch 109/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.0159 - val_accuracy: 0.9903 - val_loss: 0.0154
# Epoch 110/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9953 - loss: 0.0196 - val_accuracy: 0.9903 - val_loss: 0.0141
# Epoch 111/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9849 - loss: 0.0244 - val_accuracy: 0.9903 - val_loss: 0.0190
# Epoch 112/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.9903 - val_loss: 0.0138
# Epoch 113/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9956 - loss: 0.0125 - val_accuracy: 0.9903 - val_loss: 0.0160
# Epoch 114/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 0.9903 - val_loss: 0.0185
# Epoch 115/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9993 - loss: 0.0115 - val_accuracy: 0.9903 - val_loss: 0.0174
# Epoch 116/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9927 - loss: 0.0162 - val_accuracy: 0.9903 - val_loss: 0.0163
# Epoch 117/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9963 - loss: 0.0114 - val_accuracy: 0.9903 - val_loss: 0.0164
# Epoch 118/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9974 - loss: 0.0112 - val_accuracy: 0.9903 - val_loss: 0.0166
# Epoch 119/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9956 - loss: 0.0132 - val_accuracy: 0.9903 - val_loss: 0.0152
# Epoch 120/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9961 - loss: 0.0094 - val_accuracy: 0.9903 - val_loss: 0.0150
# Epoch 121/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9915 - loss: 0.0141 - val_accuracy: 0.9903 - val_loss: 0.0172
# Epoch 122/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9927 - loss: 0.0102 - val_accuracy: 0.9903 - val_loss: 0.0192
# Epoch 123/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.9903 - val_loss: 0.0169
# Epoch 124/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.9903 - val_loss: 0.0142
# Epoch 125/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9982 - loss: 0.0133 - val_accuracy: 0.9903 - val_loss: 0.0156
# Epoch 126/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9946 - loss: 0.0097 - val_accuracy: 0.9903 - val_loss: 0.0159
# Epoch 127/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9903 - val_loss: 0.0168
# Epoch 128/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9927 - loss: 0.0560 - val_accuracy: 0.9903 - val_loss: 0.0155
# Epoch 129/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9997 - loss: 0.0116 - val_accuracy: 0.9903 - val_loss: 0.0129
# Epoch 130/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9950 - loss: 0.0254 - val_accuracy: 0.9903 - val_loss: 0.0158
# Epoch 131/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9912 - loss: 0.0183 - val_accuracy: 0.9903 - val_loss: 0.0135
# Epoch 132/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9960 - loss: 0.0144 - val_accuracy: 0.9903 - val_loss: 0.0132
# Epoch 133/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9982 - loss: 0.0113 - val_accuracy: 0.9903 - val_loss: 0.0129
# Epoch 134/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 0.9903 - val_loss: 0.0114
# Epoch 135/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9961 - loss: 0.0582 - val_accuracy: 0.9903 - val_loss: 0.0132
# Epoch 136/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9903 - loss: 0.0157 - val_accuracy: 0.9903 - val_loss: 0.0139
# Epoch 137/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 0.9903 - val_loss: 0.0160
# Epoch 138/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.9903 - val_loss: 0.0150
# Epoch 139/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9893 - loss: 0.0215 - val_accuracy: 0.9903 - val_loss: 0.0154
# Epoch 140/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.9903 - val_loss: 0.0154
# Epoch 141/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.9903 - val_loss: 0.0134
# Epoch 142/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.9903 - val_loss: 0.0134
# Epoch 143/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9973 - loss: 0.0080 - val_accuracy: 0.9903 - val_loss: 0.0138
# Epoch 144/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9903 - val_loss: 0.0115
# Epoch 145/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.9903 - val_loss: 0.0130
# Epoch 146/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.9903 - val_loss: 0.0142
# Epoch 147/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9903 - val_loss: 0.0138
# Epoch 148/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.9903 - val_loss: 0.0134
# Epoch 149/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9903 - val_loss: 0.0124
# Epoch 150/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9903 - val_loss: 0.0136
# Epoch 151/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9990 - loss: 0.0060 - val_accuracy: 0.9903 - val_loss: 0.0132
# Epoch 152/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9903 - val_loss: 0.0125
# Epoch 153/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9985 - loss: 0.0063 - val_accuracy: 0.9903 - val_loss: 0.0121
# Epoch 154/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9995 - loss: 0.0079 - val_accuracy: 0.9903 - val_loss: 0.0115
# Epoch 155/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.9903 - val_loss: 0.0105
# Epoch 156/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9988 - loss: 0.0090 - val_accuracy: 0.9903 - val_loss: 0.0142
# Epoch 157/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.9903 - val_loss: 0.0152
# Epoch 158/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.9903 - val_loss: 0.0153
# Epoch 159/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.9903 - val_loss: 0.0140
# Epoch 160/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9901 - loss: 0.0277 - val_accuracy: 0.9903 - val_loss: 0.0109
# Epoch 161/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9974 - loss: 0.0063 - val_accuracy: 0.9903 - val_loss: 0.0132
# Epoch 162/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9978 - loss: 0.0056 - val_accuracy: 0.9903 - val_loss: 0.0122
# Epoch 163/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9968 - loss: 0.0092 - val_accuracy: 0.9903 - val_loss: 0.0142
# Epoch 164/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9968 - loss: 0.0103 - val_accuracy: 0.9903 - val_loss: 0.0150
# Epoch 165/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9985 - loss: 0.0066 - val_accuracy: 0.9903 - val_loss: 0.0138
# Epoch 166/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9988 - loss: 0.0042 - val_accuracy: 0.9903 - val_loss: 0.0135
# Epoch 167/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.9903 - val_loss: 0.0136
# Epoch 168/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9903 - val_loss: 0.0134
# Epoch 169/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.9903 - val_loss: 0.0137
# Epoch 170/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9995 - loss: 0.0051 - val_accuracy: 0.9903 - val_loss: 0.0132
# Epoch 171/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.9903 - val_loss: 0.0136
# Epoch 172/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9990 - loss: 0.0079 - val_accuracy: 0.9903 - val_loss: 0.0121
# Epoch 173/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.9903 - val_loss: 0.0110
# Epoch 174/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9961 - loss: 0.0076 - val_accuracy: 0.9903 - val_loss: 0.0118
# Epoch 175/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9982 - loss: 0.0122 - val_accuracy: 0.9903 - val_loss: 0.0133
# Epoch 176/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9982 - loss: 0.0095 - val_accuracy: 0.9903 - val_loss: 0.0143
# Epoch 177/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.9903 - val_loss: 0.0137
# Epoch 178/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9903 - val_loss: 0.0156
# Epoch 179/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.9903 - val_loss: 0.0148
# Epoch 180/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.9903 - val_loss: 0.0145
# Epoch 181/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9988 - loss: 0.0027 - val_accuracy: 0.9903 - val_loss: 0.0140
# Epoch 182/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9903 - val_loss: 0.0136
# Epoch 183/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9903 - val_loss: 0.0143
# Epoch 184/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9961 - loss: 0.0101 - val_accuracy: 0.9903 - val_loss: 0.0170
# Epoch 185/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9903 - val_loss: 0.0168
# Epoch 186/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.9903 - val_loss: 0.0143
# Epoch 187/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9903 - val_loss: 0.0130
# Epoch 188/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9903 - val_loss: 0.0136
# Epoch 189/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9903 - val_loss: 0.0136
# Epoch 190/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9903 - val_loss: 0.0141
# Epoch 191/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9985 - loss: 0.0107 - val_accuracy: 0.9903 - val_loss: 0.0128
# Epoch 192/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9903 - val_loss: 0.0124
# Epoch 193/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9860 - loss: 0.0232 - val_accuracy: 0.9903 - val_loss: 0.0101
# Epoch 194/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9924 - loss: 0.0110 - val_accuracy: 0.9903 - val_loss: 0.0089
# Epoch 195/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.9903 - val_loss: 0.0143
# Epoch 196/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9903 - val_loss: 0.0151
# Epoch 197/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.9903 - val_loss: 0.0121
# Epoch 198/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9903 - val_loss: 0.0117
# Epoch 199/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9961 - loss: 0.0052 - val_accuracy: 0.9903 - val_loss: 0.0132
# Epoch 200/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9903 - val_loss: 0.0134

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# Batch size defines number of samples that going to be propagated through the network.
#
# An Epoch is a complete pass through all the training data.

# %%
y_pred = classifier.predict(X_test)   # 0 - 1
y_pred = (y_pred >= 0.5)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, cmap="Blues", annot=True, fmt='g')
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.9714    0.9855        35
#            1     0.9565    1.0000    0.9778        22
#
#     accuracy                         0.9825        57
#    macro avg     0.9783    0.9857    0.9816        57
# weighted avg     0.9832    0.9825    0.9825        57
